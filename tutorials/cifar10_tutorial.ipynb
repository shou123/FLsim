# %% [markdown]
# # FLSim Tutorial: Image classification with CIFAR-10

# %% [markdown]
# ## Introduction
#
# In this tutorial, we will train a simple CNN image classifier on CIFAR-10 with federated learning using FLSim.

# %% [markdown]
# ### Prerequisites
#
# To get the most of this tutorial, you should be comfortable with training machine learning models with **PyTorch** and familiar with the concept of **federated learning (FL)**. If you are unfamiliar with either of them or could use a refresher, please take a look at the following resources before proceeding with the tutorial:
#
# - McMahan & Ramage (2017): [Federated Learning: Collaborative Machine Learning without Centralized Training Data](https://ai.googleblog.com/2017/04/federated-learning-collaborative.html). A short blog post from Google AI introducing the main idea of FL in a beginner-friendly way.
# - McMahan et al. (2017): [Communication-Efficient Learning of Deep Networks from Decentralized Data](https://arxiv.org/pdf/1602.05629.pdf). This paper first proposes the approach of federated learning. The described algorithm is now known as federated averaging (or FedAvg for short).
# - PyTorch has [extensive tutorials](https://pytorch.org/tutorials/) on their website. In particular, take a look at their [image classification tutorial using CIFAR-10](https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html).
#
# Now that you're familiar with PyTorch and FL, let's move on!

# %% [markdown]
# ### Objectives
#
# By the end of this tutorial, we will have learnt how to
#
# 1. Build a data pipeline for federated learning with FLSim,
# 2. Create an image classification model compatible with FL training,
# 3. Create a metrics reporter to collect and report metrics,
# 4. Set hyperparameters for FL training, and
# 5. Launch an FL training flow using FLSim.

# %% [markdown]
# ## Training an image classifier with FLSim

# %% [markdown]
# ### Prerequisites
# First, let us install flsim via pip with the command below:

# %%
# !pip install -e ../


# !pip install --quiet flsim
# Out:
# Obtaining file:///home/shiyue/flsim/FLSim
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: hydra-core>=1.1.1 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from flsim==0.1.0) (1.3.2)
# Requirement already satisfied: matplotlib in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from flsim==0.1.0) (3.7.1)
# Requirement already satisfied: omegaconf>=2.1.0 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from flsim==0.1.0) (2.3.0)
# Requirement already satisfied: numpy in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from flsim==0.1.0) (1.24.3)
# Requirement already satisfied: opacus in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from flsim==0.1.0) (1.4.0)
# Requirement already satisfied: pandas in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from flsim==0.1.0) (2.0.1)
# Requirement already satisfied: Pillow in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from flsim==0.1.0) (9.5.0)
# Requirement already satisfied: pytest in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from flsim==0.1.0) (7.3.1)
# Requirement already satisfied: scikit-learn in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from flsim==0.1.0) (1.2.2)
# Requirement already satisfied: setuptools in /home/shiyue/.local/lib/python3.8/site-packages (from flsim==0.1.0) (67.7.2)
# Requirement already satisfied: tqdm in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from flsim==0.1.0) (4.65.0)
# Requirement already satisfied: tensorboard in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from flsim==0.1.0) (2.13.0)
# Requirement already satisfied: torchvision in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from flsim==0.1.0) (0.15.2)
# Requirement already satisfied: packaging in /home/shiyue/.local/lib/python3.8/site-packages (from hydra-core>=1.1.1->flsim==0.1.0) (23.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from hydra-core>=1.1.1->flsim==0.1.0) (4.9.3)
# Requirement already satisfied: importlib-resources in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from hydra-core>=1.1.1->flsim==0.1.0) (5.12.0)
# Requirement already satisfied: PyYAML>=5.1.0 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from omegaconf>=2.1.0->flsim==0.1.0) (6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from matplotlib->flsim==0.1.0) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from matplotlib->flsim==0.1.0) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/shiyue/.local/lib/python3.8/site-packages (from matplotlib->flsim==0.1.0) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from matplotlib->flsim==0.1.0) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from matplotlib->flsim==0.1.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from matplotlib->flsim==0.1.0) (4.39.3)
# Requirement already satisfied: opt-einsum>=3.3.0 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from opacus->flsim==0.1.0) (3.3.0)
# Requirement already satisfied: scipy>=1.2 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from opacus->flsim==0.1.0) (1.10.1)
# Requirement already satisfied: torch>=1.13 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from opacus->flsim==0.1.0) (2.0.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from pandas->flsim==0.1.0) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from pandas->flsim==0.1.0) (2023.3)
# Requirement already satisfied: iniconfig in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from pytest->flsim==0.1.0) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from pytest->flsim==0.1.0) (1.0.0)
# Requirement already satisfied: tomli>=1.0.0 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from pytest->flsim==0.1.0) (2.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from pytest->flsim==0.1.0) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from scikit-learn->flsim==0.1.0) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from scikit-learn->flsim==0.1.0) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from tensorboard->flsim==0.1.0) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from tensorboard->flsim==0.1.0) (0.7.0)
# Requirement already satisfied: grpcio>=1.48.2 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from tensorboard->flsim==0.1.0) (1.54.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from tensorboard->flsim==0.1.0) (2.3.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from tensorboard->flsim==0.1.0) (2.30.0)
# Requirement already satisfied: protobuf>=3.19.6 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from tensorboard->flsim==0.1.0) (4.23.0)
# Requirement already satisfied: wheel>=0.26 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from tensorboard->flsim==0.1.0) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from tensorboard->flsim==0.1.0) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from tensorboard->flsim==0.1.0) (1.0.0)
# Requirement already satisfied: absl-py>=0.4 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from tensorboard->flsim==0.1.0) (1.4.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from torch>=1.13->opacus->flsim==0.1.0) (11.7.99)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from torch>=1.13->opacus->flsim==0.1.0) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from torch>=1.13->opacus->flsim==0.1.0) (10.9.0.58)
# Requirement already satisfied: networkx in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from torch>=1.13->opacus->flsim==0.1.0) (3.1)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from torch>=1.13->opacus->flsim==0.1.0) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from torch>=1.13->opacus->flsim==0.1.0) (11.4.0.1)
# Requirement already satisfied: typing-extensions in /home/shiyue/.local/lib/python3.8/site-packages (from torch>=1.13->opacus->flsim==0.1.0) (4.5.0)
# Requirement already satisfied: jinja2 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from torch>=1.13->opacus->flsim==0.1.0) (3.1.2)
# Requirement already satisfied: sympy in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from torch>=1.13->opacus->flsim==0.1.0) (1.11.1)
# Requirement already satisfied: filelock in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from torch>=1.13->opacus->flsim==0.1.0) (3.12.0)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from torch>=1.13->opacus->flsim==0.1.0) (8.5.0.96)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from torch>=1.13->opacus->flsim==0.1.0) (2.14.3)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from torch>=1.13->opacus->flsim==0.1.0) (11.7.4.91)
# Requirement already satisfied: triton==2.0.0 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from torch>=1.13->opacus->flsim==0.1.0) (2.0.0)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from torch>=1.13->opacus->flsim==0.1.0) (11.7.91)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from torch>=1.13->opacus->flsim==0.1.0) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from torch>=1.13->opacus->flsim==0.1.0) (11.7.101)
# Requirement already satisfied: cmake in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from triton==2.0.0->torch>=1.13->opacus->flsim==0.1.0) (3.26.3)
# Requirement already satisfied: lit in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from triton==2.0.0->torch>=1.13->opacus->flsim==0.1.0) (16.0.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->flsim==0.1.0) (4.9)
# Requirement already satisfied: six>=1.9.0 in /home/shiyue/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->flsim==0.1.0) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->flsim==0.1.0) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->flsim==0.1.0) (0.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->flsim==0.1.0) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in /home/shiyue/.local/lib/python3.8/site-packages (from importlib-resources->hydra-core>=1.1.1->flsim==0.1.0) (3.15.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/shiyue/.local/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard->flsim==0.1.0) (6.6.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard->flsim==0.1.0) (2.0.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard->flsim==0.1.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard->flsim==0.1.0) (2023.5.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard->flsim==0.1.0) (3.1.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard->flsim==0.1.0) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->flsim==0.1.0) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->flsim==0.1.0) (3.2.2)
# Requirement already satisfied: mpmath>=0.19 in /home/shiyue/anaconda3/envs/flsim_env/lib/python3.8/site-packages (from sympy->torch>=1.13->opacus->flsim==0.1.0) (1.3.0)
# Installing collected packages: flsim
#   Attempting uninstall: flsim
#     Found existing installation: flsim 0.1.0
#     Uninstalling flsim-0.1.0:
#       Successfully uninstalled flsim-0.1.0
#   Running setup.py develop for flsim
# Successfully installed flsim

# %% [markdown]
# Some useful parameters for later - no need to change these.

# %%
USE_CUDA = True
LOCAL_BATCH_SIZE = 32
EXAMPLES_PER_USER = 500
IMAGE_SIZE = 32

# suppress large outputs
VERBOSE = False

# %% [markdown]
# ### 0. About the dataset
#
# For this tutorial, we will use the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html). The CIFAR-10 dataset consists of 60k 3x32x32 3-channel color images with 32x32 pixels from 10 classes, with 6k images per class.
# There are 50k training images (5k training images per class) and 10k test images (1k test images per class).
# The classes are ‘airplane’, ‘automobile’, ‘bird’, ‘cat’, ‘deer’, ‘dog’, ‘frog’, ‘horse’, ‘ship’, and ‘truck’.
#
# ![img](https://pytorch.org/tutorials/_images/cifar10.png)
#
# We can get the CIFAR-10 dataset from `torchvision.datasets`.

# %%
from torchvision.datasets.cifar import CIFAR10

# %% [markdown]
# ### 1. Data pipeline
#
# First, let's define how to build the data pipeline for federated learning:
#
# 1. We create data transforms and training, eval, and test datasets. This step is identical to preparing data in non-federated learning.

# %%
from torchvision import transforms

# 1. Create training, eval, and test datasets like in non-federated learning.
transform = transforms.Compose(
    [
        transforms.Resize(IMAGE_SIZE),
        transforms.CenterCrop(IMAGE_SIZE),
        transforms.ToTensor(),
        transforms.Normalize(
            (0.4914, 0.4822, 0.4465), 
            (0.2023, 0.1994, 0.2010)
        ),
    ]
)
train_dataset = CIFAR10(
    root="./cifar10", train=True, download=True, transform=transform
)
test_dataset = CIFAR10(
    root="./cifar10", train=False, download=True, transform=transform
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# There are a few extra steps to enable training with federated learning. In particular, we need to
#
# 2. Create a sharder, which defines a mapping from examples in the training data to clients. In other words, a sharder groups rows of data into client datasets and returns a list of list of examples. FLSim provides a number of sharding strategies such as random or column-based sharding.
# In this tutorial, we use sequential sharding, which assigns the first `examples_per_user` rows to user 0, the second `examples_per_user` rows to user 1, etc.
#
# 3. Create a data loader, which will shard and batchify training, eval, and test data. For each dataset, the data loader first assigns rows to clients using the sharder and then splits each client's data into batches of size `batch_size`. We choose not to drop the last batch.
#
# 4. Lastly, wrap the data loader with a data provider and return it. The data provider creates clients from the groupings in the data loader and adds metadata (e.g. number of examples/batches). Our data is now formatted such that the trainer will accept it.
#
# Note that the concept of a client or device only applies to the training data, the eval and test set data are identical to non-federated learning.

# %%
from flsim.data.data_sharder import SequentialSharder
from flsim.utils.example_utils import DataLoader, DataProvider

# 2. Create a sharder, which maps samples in the training data to clients.
sharder = SequentialSharder(examples_per_shard=EXAMPLES_PER_USER)

# 3. Shard and batchify training, eval, and test data.
fl_data_loader = DataLoader(
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    test_dataset=test_dataset,
    sharder=sharder,
    batch_size=LOCAL_BATCH_SIZE,
    drop_last=False,
)

# 4. Wrap the data loader with a data provider.
data_provider = DataProvider(fl_data_loader)
print(f"\nClients in total: {data_provider.num_train_users()}")
# Out:
# Creating FL User: 100user [00:16,  6.08user/s]
# Creating FL User: 20user [00:03,  6.46user/s]
# Creating FL User: 20user [00:03,  6.55user/s]
# Clients in total: 100

# %% [markdown]
# ### 2. Create the model
#
# Now, let's see how we can create a model that is compatible with FL-training.
#
# 1. First, we define a standard, non-FL image classification PyTorch `nn.Module.` In this tutorial we use a simple CNN with 4 convolutional layers, a group norm, and a linear layer.
#
# 2. Create a `torch.device` and choose where the model will be allocated (CUDA or CPU).
#
# As with the data pipeline, these steps are identical to creating a model in non-federated learning. Note that in contrast to non-FL learning, we haven't moved the model to device yet.

# %%
import torch
from flsim.utils.example_utils import SimpleConvNet

# 1. Define our model, a simple CNN.
model = SimpleConvNet(in_channels=3, num_classes=10)

# 2. Choose where the model will be allocated.
cuda_enabled = torch.cuda.is_available() and USE_CUDA
device = torch.device(f"cuda:{0}" if cuda_enabled else "cpu")

model, device
# Out:
# (SimpleConvNet(
#    (layers): ModuleList(
#      (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#      (1-3): 3 x Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#    )
#    (gn_relu): Sequential(
#      (0): GroupNorm(32, 32, eps=1e-05, affine=True)
#      (1): ReLU()
#      (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#    )
#    (dropout): Dropout(p=0, inplace=False)
#    (fc): Linear(in_features=288, out_features=10, bias=True)
#  ),
#  device(type='cpu'))

# %% [markdown]
# As with the data pipeline, there are a few extra steps that we need to take to make sure that our model is compatible with FL. In particular, we need to
#
# 3. Wrap the PyTorch module with the FLSim `FLModel`, an abstracted version of a FL-friendly model class that is accepted by the trainer and handles metric collection, as well as the forward pass for both training and evaluation. We can recover our `nn.Module` by calling `FLModel.fl_get_module()`
#
# 4. Move the model to GPU and enable CUDA if desired. `FLModel.fl_cuda()` internally calls `model.to(device)` to move the model to GPU.

# %%
from flsim.utils.example_utils import FLModel

# 3. Wrap the model with FLModel.
global_model = FLModel(model, device)
assert(global_model.fl_get_module() == model)

# 4. Move the model to GPU and enable CUDA if desired.
if cuda_enabled:
    global_model.fl_cuda()

# %% [markdown]
# ### 3. Metrics Reporting
#
# After having created our data pipeline and FL model, we will now create our metrics reporter.
# The metrics reporter allows us to collect, evaluate, and report relevant training, aggregation, and evaluation/test metrics as well as log them onto TensorBoard.

# %%
from flsim.interfaces.metrics_reporter import Channel
from flsim.utils.example_utils import MetricsReporter

# Create a metric reporter.
metrics_reporter = MetricsReporter([Channel.TENSORBOARD, Channel.STDOUT])

# %% [markdown]
# There are three functions that are of particular interest:
#
# 1. `compute_scores` computes the metrics of interest for both training and aggregation (if desired) as well as evaluation/test.
#
# 2. `create_eval_metrics` creates a dictionary that stores the value for each eval metric.
#
# 3. `compare_metrics` compares the current eval metrics that are returned by `create_eval_metrics` to the best eval metrics so far.
#
#
# For this tutorial, our only metric of interest is top-1 accuracy. In general, as with the data loading and model, you should write your own metrics reporter depending on the task. For example, if you are running an NLP task you may want to have your metrics reporter track perplexity as well.

# %%
import inspect

if VERBOSE:
    print(inspect.getsource(MetricsReporter.compute_scores))
    print(inspect.getsource(MetricsReporter.create_eval_metrics))
    print(inspect.getsource(MetricsReporter.compare_metrics))

# %% [markdown]
# ### 4. Hyperparameters
#
# We can represent the hyperparameters for FL training in a JSON config for ease of representation and we convert the JSON config to OmegaConf before passing it to the FL trainer.
#
# In particular, we specify a FedAvg implementation with 10 users per round.

# %%
import flsim.configs
from flsim.utils.config_utils import fl_config_from_json
from omegaconf import OmegaConf

json_config = {
    "trainer": {
        "_base_": "base_sync_trainer",
        # there are different types of aggregator
        # fed avg doesn't require lr, while others such as fed_avg_with_lr or fed_adam do
        "_base_": "base_sync_trainer",
        "server": {
            "_base_": "base_sync_server",
            "server_optimizer": {
                "_base_": "base_fed_avg_with_lr",
                "lr": 2.13,
                "momentum": 0.9
            },
            # type of user selection sampling
            "active_user_selector": {"_base_": "base_uniformly_random_active_user_selector"},
        },
        "client": {
            # number of client's local epoch
            "epochs": 1,
            "optimizer": {
                "_base_": "base_optimizer_sgd",
                # client's local learning rate
                "lr": 0.01,
                # client's local momentum
                "momentum": 0,
            },
        },
        # number of users per round for aggregation
        "users_per_round": 50,
        # total number of global epochs
        # total #rounds = ceil(total_users / users_per_round) * epochs
        "epochs": 1,
        # frequency of reporting train metrics
        "train_metrics_reported_per_epoch": 100,
        # frequency of evaluation per epoch
        "eval_epoch_frequency": 1,
        "do_eval": True,
        # should we report train metrics after global aggregation
        "report_train_metrics_after_aggregation": True,
    }
}
cfg = fl_config_from_json(json_config)
if VERBOSE: print(OmegaConf.to_yaml(cfg))

# %% [markdown]
# ### 5. Training
# Recall that we already built the data provider and created a model compatible with FL training.
# We also initialized a metrics reporter and set our desired hyperparameters.
#
# Now, we only need to instantiate the trainer with the model and hyperparameter config we defined earlier to launch the FL training flow. We run FL training with the above JSON config and utilize `eval_score` to store the final evaluation metrics.

# %%
from hydra.utils import instantiate

# Instantiate the trainer.
trainer = instantiate(cfg.trainer, model=global_model, cuda_enabled=cuda_enabled)   

# Launch FL training.
final_model, eval_score = trainer.train(
    data_provider=data_provider,
    metrics_reporter=metrics_reporter,
    num_total_users=data_provider.num_train_users(),
    distributed_world_size=1
)
# Out:
# num_users_on_worker: 100
# users_per_round: 50
# num_total_users: 100
# users_per_round_on_worker: 50
# =======Start trainin======
# ======Main training loop======
# Round:   0%|          | 0/2 [00:00<?, ?round/s]
# client select index: [96, 98, 19, 29, 33, 81, 18, 62, 21, 45, 42, 13, 16, 51, 67, 52, 66, 56, 41, 58, 25, 32, 6, 84, 68, 94, 91, 46, 59, 7, 95, 53, 38, 11, 86, 30, 44, 48, 74, 60, 92, 77, 80, 63, 55, 76, 73, 43, 35, 82]
# Client training took: 0.40653562545776367 s.
# # clients/round on worker 0: 50.
# Round initialization took 0.0005712509155273438 s.
# Update client-side models from server-side model took 9.130096912384033 s.
# After all clients finish their updates, update the global model: 0.002378225326538086 s.
# Train finished Global Round: 1
# (epoch = 1, round = 1, global round = 1), Loss/Training: 2.331881695538759
# (epoch = 1, round = 1, global round = 1), Accuracy/Training: 13.704
# Round:  50%|█████     | 1/2 [00:12<00:12, 12.41s/round]
# (epoch = 1, round = 1, global round = 1), Loss/Aggregation: 2.301466348618269
# (epoch = 1, round = 1, global round = 1), Accuracy/Aggregation: 16.924
# Report evaluation metric on evaluation clients
# Evaluation took 6.556510925292969e-05 s.
# client select index: [4, 60, 30, 92, 80, 42, 76, 78, 71, 47, 91, 10, 88, 52, 28, 62, 63, 41, 72, 97, 25, 54, 55, 64, 3, 12, 16, 85, 1, 58, 31, 29, 89, 24, 59, 84, 75, 5, 7, 11, 96, 73, 8, 82, 33, 98, 87, 95, 17, 86]
# Client training took: 0.3999366760253906 s.
# # clients/round on worker 0: 50.
# Round initialization took 0.0005979537963867188 s.
# Update client-side models from server-side model took 8.499122619628906 s.
# After all clients finish their updates, update the global model: 0.0032711029052734375 s.
# Train finished Global Round: 2
# (epoch = 1, round = 2, global round = 2), Loss/Training: 2.114969270825386
# (epoch = 1, round = 2, global round = 2), Accuracy/Training: 23.412
# (epoch = 1, round = 2, global round = 2), Loss/Aggregation: 1.9864390839636326
# (epoch = 1, round = 2, global round = 2), Accuracy/Aggregation: 27.196
# Report evaluation metric on evaluation clients
# (epoch = 1, round = 2, global round = 2): 	 Evaluates global model on all data of eval users
# (epoch = 1, round = 2, global round = 2), Loss/Eval: 1.9902694284915925
# (epoch = 1, round = 2, global round = 2), Accuracy/Eval: 27.68
# Round:  50%|█████     | 1/2 [00:25<00:25, 25.11s/round]
# Epoch:   0%|          | 0/1 [00:25<?, ?epoch/s]
# Evaluation took 1.0883734226226807 s.

# %% [markdown]
# After training finishes, we evaluate the model and report the accuracy on the test set before finishing this tutorial.

# %%
# We can now test our trained model.
trainer.test(
    data_provider=data_provider,
    metrics_reporter=MetricsReporter([Channel.STDOUT]),
)
# Out:
# Running (epoch = 1, round = 1, global round = 1) for Test
# (epoch = 1, round = 1, global round = 1), Loss/Test: 1.9902694284915925
# (epoch = 1, round = 1, global round = 1), Accuracy/Test: 27.68
# {'Accuracy': 27.68}

# %% [markdown]
# ## Summary
#
# In this tutorial, we first showed how to get the data. We then built a data provider by sharding the data to simulate multiple client devices, each with their own data, and splitting each client's data into batches.
# We defined a simple CNN as our model, wrapped it with a model compatible with FL training, and moved it to GPU.
# Lastly, we set the hyperparameters for FL training, launched the training flow, and evaluated our model.

# %% [markdown]
# ### Additional resources
#
# - For a more in-depth understanding of this tutorial, check out [example_utils.py](https://github.com/facebookresearch/FLSim/blob/main/flsim/utils/example_utils.py) where we define the data loader, data provider, simple CNN, `FLModel`, and metrics reporter that we use in this tutorial.
#
# - [FLSim tutorials](https://github.com/facebookresearch/FLSim/tree/main/tutorials) - check out our other tutorial on sentiment classification.
#
# - Kairouz et al. (2021): [Advances and Open Problems in Federated Learning](https://arxiv.org/pdf/1912.04977.pdf). As the title suggests, an in-depth overview of advances and open problems in FL.
#
# - If you're interested in federated learning with differential privacy, take a look at [Opacus](https://opacus.ai/), a library that enables training PyTorch models with differential privacy.
# You can find a blog post introducing Opacus [here](https://ai.facebook.com/blog/introducing-opacus-a-high-speed-library-for-training-pytorch-models-with-differential-privacy/).
